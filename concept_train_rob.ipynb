# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Feb__7_19:32:13_PST_2023
# Cuda compilation tools, release 12.1, V12.1.66
# Build cuda_12.1.r12.1/compiler.32415258_0

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import concept_model
import helper
from utils.log import setup_logger
from utils.ood_utils import run_ood_over_batch
from utils.test_utils import get_measures
# from test_baselines import run_eval

import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K


import tensorflow.keras.utils as utils
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.layers as layers

from utils.ood_utils import run_ood_over_batch
from utils.test_utils import get_measures
from utils.stat_utils import multivar_separa 

import os
import argparse
import logging
import numpy as np
import sys
import time
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


physical_devices = tf.config.experimental.list_physical_devices('GPU')
try:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

print(tf.config.experimental.list_physical_devices())
# Out:
# 2024-08-12 03:34:39.501885: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-12 03:34:39.831700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-12 03:34:39.949938: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-12 03:34:39.984627: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-12 03:34:40.187849: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-12 03:34:42.464673: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class ARGS:
    def __init__(self):
        self.gpu = "0"
        self.batch_size = 256
        self.epoch = 40
        self.opt = "adam"
        self.thres = 0
        self.val_step = 2
        self.save_step = 1
        self.offset = 0
        self.trained = False
        self.num_concepts = 100

        self.coeff_concept = 10
        self.feat_l2 = True
        self.coeff_feat = 0.1
        self.feat_cosine = False
        self.coeff_cosine = 1
        self.ood = True
        self.score = "energy"
        self.coeff_score = 1 # 
        self.separability = True
        self.coeff_separa = 50

        self.num_hidden = 2

        self.out_data = "MSCOCO" # "augAwA"
        self.temperature_odin = 1000
        self.epsilon_odin = 0.0
        self.temperature_energy = 1
        
        self.name = "AwA2_2_feat_l2_0.1_ood_1_sep_50_rob" # AwA2_baseline, AwA2_feat_l2_0.1_ood_1_sep_50
        self.logdir = "results/"+self.name+"/train_logs"

args = ARGS()

# %%
def get_data(bs, ood=True):
    """
    prepare data loaders for ID and OOD data (train/test)
    :param bs: batch size
    :ood: whether to load OOD data as well (False for baseline concept learning by Yeh et al.)
    """

    TRAIN_DIR = "data/AwA2/train"
    VAL_DIR = "data/AwA2/val"
    TEST_DIR = "data/AwA2/test"
    if args.out_data == 'MSCOCO':
        OOD_DIR = "data/MSCOCO"
    elif args.out_data == 'augAwA':
        OOD_DIR = "data/AwA2-train-fractals"

    TARGET_SIZE = (224, 224)
    BATCH_SIZE = bs
    BATCH_SIZE_OOD = bs

    print('Loading images through generators ...')
    train_datagen = ImageDataGenerator(rescale=1. / 255.,
                                       rotation_range=30,
                                       width_shift_range=0.2,
                                       height_shift_range=0.2,
                                       shear_range=0.2,
                                       zoom_range=0.2,
                                       horizontal_flip=True)
    train_loader = train_datagen.flow_from_directory(TRAIN_DIR,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=TARGET_SIZE,
                                                    class_mode='categorical',
                                                    shuffle=True)

    #print(train_generator.class_indices.items())

    datagen = ImageDataGenerator(rescale=1.0 / 255.)
    val_loader = datagen.flow_from_directory(VAL_DIR,
                                            batch_size=BATCH_SIZE,
                                            target_size=TARGET_SIZE,
                                            class_mode='categorical',
                                            shuffle=False)
    test_loader = datagen.flow_from_directory(TEST_DIR,
                                            batch_size=BATCH_SIZE,
                                            target_size=TARGET_SIZE,
                                            class_mode='categorical',
                                            shuffle=False)
    if ood:
        #numUpdates = int(NUM_TRAIN / BATCH_SIZE) # int(f_train.shape[0] / BATCH_SIZE)
        #NUM_OOD = 31706
        #BATCH_SIZE_OOD = int(NUM_OOD / numUpdates)
        OOD_loader = train_datagen.flow_from_directory(OOD_DIR, #datagen
                                                batch_size=BATCH_SIZE_OOD,
                                                target_size=TARGET_SIZE,
                                                class_mode=None, shuffle=True)
    else:
        OOD_loader = None

    return train_loader, val_loader, test_loader, OOD_loader


def get_class_labels(loader, savepath):
    """
    extract groundtruth class labels from data loader
    :param loader: data loader
    :param savepath: path to the numpy file
    """

    if os.path.exists(savepath):
        y = np.load(savepath)
    else:
        num_data = len(loader.filenames)
        y = []
        for (_, y_batch), _ in zip(loader, range(len(loader))):
            y.extend(y_batch)
       
        np.save(savepath, y)
    return y

def run_eval(feature_model, predict_model, in_loader, out_loader, logger, args, num_classes):
    in_scores = np.array([])
    for i, (x, y) in enumerate(in_loader):
        if i == len(in_loader):
            break
        score = run_ood_over_batch(x, feature_model, predict_model, args, num_classes).numpy()
        in_scores = np.concatenate([in_scores, score])
    out_scores = np.array([])
    for i, x in enumerate(out_loader):
        if i == len(in_loader):
            break
        score = run_ood_over_batch(x, feature_model, predict_model, args, num_classes).numpy()
        out_scores = np.concatenate([out_scores, score])
    in_examples = np.expand_dims(in_scores, axis=1)
    out_examples = np.expand_dims(out_scores, axis=1)
    auroc, aupr_in, aupr_out, fpr, thres95 = get_measures(in_examples, out_examples)
    return in_scores, out_scores, auroc, fpr, thres95

def gaussian_blur(img, kernel_size=11, sigma=5):
    def gauss_kernel(channels, kernel_size, sigma):
        ax = tf.range(-kernel_size // 2 + 1.0, kernel_size // 2 + 1.0)
        xx, yy = tf.meshgrid(ax, ax)
        kernel = tf.exp(-(xx ** 2 + yy ** 2) / (2.0 * sigma ** 2))
        kernel = kernel / tf.reduce_sum(kernel)
        kernel = tf.tile(kernel[..., tf.newaxis], [1, 1, channels])
        return kernel
    
    gaussian_kernel = gauss_kernel(tf.shape(img)[-1], kernel_size, sigma)
    gaussian_kernel = gaussian_kernel[..., tf.newaxis]
    
    return tf.nn.depthwise_conv2d(np.expand_dims(img, axis=0), gaussian_kernel, [1, 1, 1, 1],
                                  padding='SAME', data_format='NHWC')

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = args.gpu

#if not os.path.exists(args.output_dir):
#    os.makedirs(args.output_dir)

if args.separability:
    args.ood = True
USE_OOD = args.ood
BATCH_SIZE = args.batch_size
EPOCH = args.epoch
THRESHOLD = args.thres
trained = args.trained
N_CONCEPT = args.num_concepts
offset = args.offset
topic_modelpath = os.path.join(args.logdir, args.name,'topic_epoch{}.weights.h5'.format(offset))
#topic_modelpath = os.path.join(args.logdir, args.name,'topic_latest.h5')
topic_savepath = os.path.join(args.logdir, args.name,'topic_vec_inceptionv3.npy')

logger = setup_logger(args)

train_loader, val_loader, test_loader, ood_loader =  get_data(BATCH_SIZE, ood=USE_OOD)

#print(train_generator.class_indices.items())
#assert ('_OOD', 0) in val_generator.class_indices.items()
#y_train = get_class_labels(train_loader, savepath='data/Animals_with_Attributes2/y_train.npy')
y_val = get_class_labels(val_loader, savepath='data/AwA2/y_val.npy')
y_test = get_class_labels(test_loader, savepath='data/AwA2/y_test.npy')

# preds_cls_idx = y_test.argmax(axis=-1)
# idx_to_cls = {v: k for k, v in test_generator.class_indices.items()}
# preds_cls = np.vectorize(idx_to_cls.get)(preds_cls_idx)
# filenames_to_cls = list(zip(test_generator.filenames, preds_cls))


# Loads model
feature_model, predict_model = helper.load_model_inception_new(train_loader, val_loader, \
           batch_size=BATCH_SIZE, input_size=(224,224), pretrain=True, \
           modelname='./results/AwA2/inceptionv3_AwA2_rob_ep_49.weights.h5', split_idx=-5)
# Out:
# 2024-08-12 03:34:51,459 [INFO] utils.log: <__main__.ARGS object at 0x7f1a74030610>
# Loading images through generators ...
# Found 29841 images belonging to 50 classes.
# Found 3709 images belonging to 50 classes.
# Found 3772 images belonging to 50 classes.
# Found 40670 images belonging to 1 classes.
# 2024-08-12 03:34:55.836555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31141 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:af:00.0, compute capability: 7.0
# original model to be trained
# /home/dingw/.conda/envs/adv_train/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /home/dingw/.conda/envs/adv_train/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723426518.041243 1257438 service.cc:146] XLA service 0x7f19c40038e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1723426518.041327 1257438 service.cc:154]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2024-08-12 03:35:18.300287: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-12 03:35:19.312712: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8900
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 5:40 24s/step - accuracy: 0.7695 - loss: 1.1101
# 2024-08-12 03:35:33.368807: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_reduce_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1723426533.398660 1257438 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.8574 - loss: 0.7966
# Loss of the trained original model: 0.7304525971412659
# Accuracy of the trained original model: 0.8759773373603821
# 2024-08-12 03:36:46.056047: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_reduce_fusion', 4 bytes spill stores, 8 bytes spill loads
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_2 (InputLayer)            │ (None, 5, 5, 2048)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 2048)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │        12,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 537,394 (2.05 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 537,394 (2.05 MB)
# None

# %%
## Concept Learning
x, _ = test_loader.__next__()
f = feature_model(x[:10])
# topic model: intermediate feature --> concept score --> recovered feature --> prediction (50 classes)
topic_model_pr = concept_model.TopicModel(f, N_CONCEPT, THRESHOLD, predict_model, args.num_hidden)
_ = topic_model_pr(f)
print(topic_model_pr.build_graph(f).summary())

if os.path.exists(topic_modelpath):
    topic_model_pr.load_weights(topic_modelpath)
    logger.info(f'topic model loaded from {topic_modelpath}')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1723426611.044710 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.095545 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.095875 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.096172 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.096461 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.096761 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.097063 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.097374 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.097689 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.098008 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.098333 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.098674 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.099030 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.099388 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.099742 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.100100 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.100545 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.101025 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.464016 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.464584 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.465059 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.465506 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.465950 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.466386 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.466885 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.467361 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.467874 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.468387 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.468927 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.469505 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.470088 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.470703 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.471623 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.472493 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.473422 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.474094 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.475119 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.475930 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.477554 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.479533 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.480798 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.493115 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.493817 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.494381 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.494942 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.495752 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.496342 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.496941 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.497538 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.498156 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.498817 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.499535 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.500277 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.501033 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.501768 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.502766 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.503627 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.504774 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.505758 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.506818 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.508452 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.510428 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.512416 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.631457 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.632233 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.633142 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.633985 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.634839 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.635701 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.636559 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.637495 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.638377 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.639283 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.640318 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.641362 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.642121 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.643216 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.644228 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.645415 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.646538 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.647679 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.648884 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.649954 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.651129 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.652427 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.654517 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.675605 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.675942 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.676279 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.676614 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.676946 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.677310 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.677680 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.678017 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.678394 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.678743 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.679106 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.679444 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.679801 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.680141 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.680519 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.680907 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.681294 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.681769 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.682111 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.682516 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.682924 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.683300 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.755638 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.756027 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.756409 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.756798 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.757182 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.757602 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.758034 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.758418 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.758864 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.759258 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.759687 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.760072 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.760496 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.760887 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.761389 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.761828 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.762292 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.762902 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.763321 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.763778 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.764235 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.764675 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.775086 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.775454 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.775795 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.776178 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.776548 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.777008 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.777405 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.777802 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.778194 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.778534 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.778961 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.779363 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.779678 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.780054 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.780415 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.780797 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.781324 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.781794 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.782226 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.782693 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.783399 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.784167 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.857882 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.858209 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.858514 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.858816 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.859118 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.859449 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.859804 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.860135 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.860473 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.860818 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.861177 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.861530 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.861881 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.862258 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.862632 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.863022 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.863411 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.863972 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.864392 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.872805 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.873345 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.873907 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.874515 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.875131 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.875766 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.876285 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.876794 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.877333 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.877888 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.878483 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.879081 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.879670 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.880395 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.881101 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.881784 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.882503 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.883284 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.884137 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.901998 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.902342 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.902652 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.903011 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.903376 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.903732 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.904092 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.904448 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.904755 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.905065 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.905468 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.905847 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.906184 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.906611 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.906988 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.907297 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.907700 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.908240 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.908756 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.916415 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.916754 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.917069 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.917362 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.917712 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.918115 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.918458 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.918868 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.919301 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.919656 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.920025 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.920599 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.920910 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.938252 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.938629 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.939046 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.939396 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.939743 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.940040 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.940410 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.940749 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.941123 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.941548 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.941890 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.942201 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.942590 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.942890 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.943231 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.943702 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.944015 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.944358 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.945029 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.945684 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.952331 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.952675 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.952975 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.953314 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.953668 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.954013 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.954370 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.954722 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.955025 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.955331 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.955728 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.956103 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.956444 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.956872 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.957241 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.957575 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.957966 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.958478 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.959154 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.959807 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.979345 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.979698 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.980007 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.980363 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.980747 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.981121 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.981501 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.981873 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.982192 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.982514 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.982954 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.983361 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.983720 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.984191 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.984579 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.984902 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.985325 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.985878 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.986652 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.987404 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.996335 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.996695 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.997008 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.997332 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.997652 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.997981 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.998332 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.998695 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.999054 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.999435 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426611.999813 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.000206 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.000572 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.000972 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.001401 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.001853 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.002328 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.002848 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.003512 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.004283 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.021395 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.021796 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.022255 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.022637 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.023019 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.023328 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.023725 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.024086 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.024481 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.024954 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.025319 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.025641 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.026068 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.026383 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.026736 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.027252 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.027570 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.027930 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.028797 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.029647 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.036379 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.036732 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.037038 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.037397 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.037781 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.038154 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.038536 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.038914 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.039234 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.039553 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.039989 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.040391 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.040757 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.041228 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.041619 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.041975 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.042402 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.042959 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.043827 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.044676 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.090013 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.090378 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.090702 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.091091 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.091504 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.091904 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.092315 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.092715 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.093048 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.093390 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.093868 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.094307 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.094693 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.095213 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.095616 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.095990 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.096456 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.097060 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.098076 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.099088 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.108469 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.108894 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.109396 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.109807 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.110214 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.110528 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.110958 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.111344 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.111772 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.112293 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.112684 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.113022 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.113492 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.113827 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.114195 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.114760 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.115094 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.115478 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.116496 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.117492 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.156540 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.156905 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.157253 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.157584 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.157933 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.158314 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.158752 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.159202 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.159683 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.160134 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.160621 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.161099 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.161523 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.162059 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.162585 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.163122 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.163659 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.164261 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.164913 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.165506 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.173976 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.174352 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.174702 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.175031 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.175380 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.175755 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.176186 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.176631 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.177107 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.177556 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.178034 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.178510 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.178932 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.179456 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.179978 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.180520 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.181053 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.181653 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.182303 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.200293 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.200701 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.201144 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.201606 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.202275 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.203081 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.203768 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.204279 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.205146 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.205964 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.206777 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.207308 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.207795 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.208449 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.209483 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.210300 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.211374 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.212492 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.213451 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.213974 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.215407 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.216824 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.219451 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.232375 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.232718 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.233053 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.233371 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.233691 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.234057 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.234435 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.234846 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.235243 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.235634 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.236037 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.236430 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.236790 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.237217 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.237659 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.238099 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.238575 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.239124 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.240081 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.247040 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.247396 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.247701 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.248026 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.248395 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.248762 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.249160 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.249548 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.249956 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.250357 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.250722 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.251153 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.251595 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.252044 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.252445 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.252925 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.253462 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.253787 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723426612.254575 1257152 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ f_input             │ (None, 5, 5,      │          0 │ -                 │
# │ (InputLayer)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 5, 5,      │          0 │ f_input[0][0]     │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ weight (Weight)     │ (2048, 100)       │    204,800 │ lambda_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mat_mul (MatMul)    │ (None, 5, 5,      │          0 │ f_input[0][0],    │
# │                     │ 2048)             │            │ weight[0][0],     │
# │                     │                   │            │ lambda_8[0][0],   │
# │                     │                   │            │ weight[0][0],     │
# │                     │                   │            │ lambda_11[0][0],  │
# │                     │                   │            │ weight_1[0][0],   │
# │                     │                   │            │ re_lu[0][0],      │
# │                     │                   │            │ weight_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 5, 5, 100) │          0 │ mat_mul[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 5, 5, 100) │          0 │ mat_mul[0][0],    │
# │                     │                   │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 5, 5, 1)   │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_11 (Lambda)  │ (None, 5, 5, 100) │          0 │ multiply[0][0],   │
# │                     │                   │            │ lambda_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ weight_1 (Weight)   │ (100, 500)        │     50,000 │ f_input[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 5, 5, 500) │          0 │ mat_mul[2][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ weight_2 (Weight)   │ (500, 2048)       │  1,024,000 │ f_input[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_2        │ (None, 50)        │    537,394 │ mat_mul[3][0]     │
# │ (Functional)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,816,194 (6.93 MB)
#  Trainable params: 1,278,800 (4.88 MB)
#  Non-trainable params: 537,394 (2.05 MB)
# None

# %%
## Concept Learning

if args.opt =='sgd':
    """
    optimizer = SGD(lr=0.1)
    optimizer_state = [optimizer.iterations, optimizer.lr, optimizer.momentum, optimizer.decay]
    optimizer_reset = tf.compat.v1.variables_initializer(optimizer_state)
    """
    optimizer = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
elif args.opt =='adam':
    optimizer = Adam(learning_rate=0.01)
    optimizer_state = [optimizer.iterations, optimizer.learning_rate, optimizer.beta_1, optimizer.beta_2, optimizer.weight_decay]
    optimizer_reset = tf.compat.v1.variables_initializer(optimizer_state)

train_acc_metric = keras.metrics.CategoricalAccuracy()
val_acc_metric = keras.metrics.CategoricalAccuracy()
test_acc_metric = keras.metrics.CategoricalAccuracy()
softmax = layers.Activation('softmax')

@tf.function
def train_step(x_in, y_in, x_out=None, thres=None):
    #tf.keras.applications.inception_v3.preprocess_input(x_in)
    f_in = feature_model(x_in)
    f_in_n = K.l2_normalize(f_in,axis=(3))


    obj_terms = {} # terms in the objective function
    COEFF_CONCEPT = args.coeff_concept #10 -> 5 -> 1 
    with tf.GradientTape() as tape:
        f_in_recov, logits_in, topic_vec_n = topic_model_pr(f_in, training=True)
        pred_in = softmax(logits_in) # class prediction using concept scores
        topic_prob_in_n = K.dot(f_in_n, topic_vec_n) # normalized concept scores

        # total loss
        CE_IN = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_in, pred_in))
        loss_coherency = tf.reduce_mean(tf.nn.top_k(K.transpose(K.reshape(topic_prob_in_n,(-1,N_CONCEPT))),k=10,sorted=True).values)
        loss_similarity = tf.reduce_mean(K.dot(K.transpose(topic_vec_n), topic_vec_n) - tf.eye(N_CONCEPT))
        loss = CE_IN - COEFF_CONCEPT*loss_coherency + COEFF_CONCEPT*loss_similarity  # baseline: Yeh et al.
        obj_terms['[ID] CE'] = CE_IN
        obj_terms['[ID] concept coherency'] = loss_coherency
        obj_terms['[ID] concept similarity'] = loss_similarity
        #print('y_in: '+type(y_in).__name__)
        #print('pred_in: '+type(pred_in).__name__)
        #print('CE_IN: '+type(CE_IN).__name__)
        #print('loss coher: '+type(loss_coherency).__name__)
        #print('loss_sim: '+type(loss_similarity).__name__)
        #print('loss: '+type(loss).__name__)
        
        if args.feat_l2:
            loss_l2 = tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.pow(f_in-f_in_recov,2), axis=(1,2,3))))
            #loss_l2 = tf.reduce_mean(tf.reduce_sum(tf.pow(f_in-f_in_recov,2), axis=(1,2,3)))
            loss += args.coeff_feat*loss_l2 #0.07, 0.02
            obj_terms['feature L2'] = loss_l2

        if args.feat_cosine:
            loss_cosine = tf.reduce_mean(tf.keras.losses.cosine_similarity(f_in, f_in_recov)) # equivalent to: tf.reduce_mean(tf.reduce_sum(tf.math.multiply(f_in, f_in_recov),axis=(1,2,3))/(tf.sqrt(tf.reduce_sum(tf.pow(f_in,2),axis=(1,2,3)))*tf.sqrt(tf.reduce_sum(tf.pow(f_in_recov,2),axis=(1,2,3)))))
            loss_cosine = 1 - loss_cosine # cosine distance, range=[0, 2]
            loss += args.coeff_cosine*loss_cosine
            obj_terms['feature cosine distance'] = loss_cosine
        
        if args.score:
            s_in = run_ood_over_batch(x_in, feature_model, predict_model, args, num_classes=50)
            s_out = run_ood_over_batch(x_out, feature_model, predict_model, args, num_classes=50)

            if args.coeff_score > 0.0:
                # scores from OOD detector when using recovered features
                s_in_recov = run_ood_over_batch(x_in, feature_model, topic_model_pr, args, num_classes=50)
                s_out_recov = run_ood_over_batch(x_out, feature_model, topic_model_pr, args, num_classes=50)

                s_original = tf.concat((s_in, s_out), axis=0)
                s_recovered = tf.concat((s_in_recov, s_out_recov), axis=0)
                loss_score = tf.reduce_mean(tf.pow(s_original - s_recovered, 2))
                loss += args.coeff_score*loss_score
                obj_terms['score difference'] = loss_score

                """
                # Debugging
                auroc, aupr_in, aupr_out, fpr95, thres95 = get_measures(s_in.numpy()[:,None], s_out.numpy()[:,None])
                print(f'auroc: {auroc}, aupr in: {aupr_in}, aupr out: {aupr_out}, fpr95: {fpr95}')
                auroc, aupr_in, aupr_out, fpr95, thres95 = get_measures(s_in_recov.numpy()[:,None], s_out_rec
ov.numpy()[:,None])
                print(f'auroc: {auroc}, aupr in: {aupr_in}, aupr out: {aupr_out}, fpr95: {fpr95}')
                input()
                """
        
        if args.separability:
            f_out = feature_model(x_out)
            f_out_n = K.l2_normalize(f_out,axis=(3))
            _, logits_out, _ = topic_model_pr(f_out, training=True)
            #tf.debugging.assert_equal(topic_vec_n, topic_vec_n_out) 
            topic_prob_out_n = K.dot(f_out_n, topic_vec_n)
            

            # max --> smoothly approximated by logsumexp
            #T = tf.Variable(1e+3, dtype=tf.float32)
            T = 1e+3
            prob_max_in = 1/T*tf.math.reduce_logsumexp(T*topic_prob_in_n,axis=(1,2))
            prob_min_in = -1/T*tf.math.reduce_logsumexp(-T*topic_prob_in_n,axis=(1,2))

            ## concept scores of "true" ID set and "true" OOD set
            concept_in_true = tf.where(tf.abs(prob_max_in) > tf.abs(prob_min_in), prob_max_in, prob_min_in)
            prob_max_out = 1/T*tf.math.reduce_logsumexp(T*topic_prob_out_n,axis=(1,2))
            prob_min_out = -1/T*tf.math.reduce_logsumexp(-T*topic_prob_out_n,axis=(1,2))
            concept_out_true = tf.where(tf.abs(prob_max_out) > tf.abs(prob_min_out), prob_max_out, prob_min_out)
            
            ## concept scores of "detected" ID set and "detected" OOD set
            concept_in = tf.concat([concept_in_true[s_in>=thres], concept_out_true[s_out>=thres]], axis=0) 
            concept_out = tf.concat([concept_in_true[s_in<thres], concept_out_true[s_out<thres]], axis=0)

            # global separability
            loss_separa = multivar_separa(concept_in, concept_out)
            loss -= args.coeff_separa*loss_separa
            obj_terms['separability'] = loss_separa

    obj_terms['total loss.......'] = loss
    train_acc_metric.update_state(y_in, logits_in)
    #print(obj_terms)

    # calculate the gradients using our tape and then update the model weights
    grads = tape.gradient(loss, topic_model_pr.trainable_variables)
    optimizer.apply_gradients(zip(grads, topic_model_pr.trainable_variables))
    #print(type(loss).__name__, ":", grads)
    #input()
    return obj_terms

if not trained:
    for layer in topic_model_pr.layers[:-1]:
        #print(layer.trainable)
        layer.trainable = True

    # check all weights are included in trainable_variables
    # for i, var in enumerate(topic_model_pr.trainable_variables):
    #     print(topic_model_pr.trainable_variables[i].name)


    if args.score and args.separability: # identify threshold from held-out set
        datagen = ImageDataGenerator(rescale=1.0 / 255.)
        if args.out_data == 'MSCOCO':
            out_gen = datagen.flow_from_directory('data/MSCOCO/test',batch_size=150,target_size=(224,224),class_mode=None,shuffle=False)
        elif args.out_data == 'augAwA':
            out_gen = datagen.flow_from_directory('data/AwA2-test-fractals',batch_size=150,target_size=(224,224),class_mode=None,shuffle=False)
        _, _, _, _, thres = run_eval(feature_model, predict_model, val_loader, out_gen, logger, args, 50)
        thres = float(thres)
    else:
        thres = None

    df_obj_terms = pd.DataFrame()
    for epoch in range(offset+1, offset+EPOCH+1):
        logger.info(f"\n[INFO] starting epoch {epoch}/{offset+EPOCH} ---------------------------------")
        sys.stdout.flush()
        epochStart = time.time()
        
        for step, (x_in, y_in) in enumerate(train_loader):
            
            s = np.random.uniform(0, 1, size=6) > 0.5
            if s[4]:
              sigma = np.random.uniform(0.2, 0.8, size=len(x_in))
              for i_, sig in enumerate(sigma):
                x_in[i_] = gaussian_blur(x_in[i_], kernel_size=10, sigma=sig)
            if s[0]:
              x_in= tf.image.random_hue(x_in, 0.1, seed=None)
            if s[1]:
              x_in = tf.image.random_brightness(x_in, 0.3, seed=None)
            if s[2]:
              x_in = tf.image.random_contrast(x_in, 0.7, 1)
            if s[3]:
              saturation_factor = np.random.uniform(0.5, 1)
              x_in = tf.image.adjust_saturation(x_in, saturation_factor)
            
            if s[5]:
              x_in += np.random.uniform(0, 0.1, size=x_in.shape)
            
            step += 1 # starts from 1
            if step > len(train_loader):
                break

            if USE_OOD:
                x_out = ood_loader.__next__()
                
                s = np.random.uniform(0, 1, size=6) > 0.5
                if s[4]:
                  sigma = np.random.uniform(0.2, 0.8, size=len(x_out))
                  for i_, sig in enumerate(sigma):
                    x_out[i_] = gaussian_blur(x_out[i_], kernel_size=10, sigma=sig)
                if s[0]:
                  x_out = tf.image.random_hue(x_out, 0.1, seed=None)
                if s[1]:
                  x_out = tf.image.random_brightness(x_out, 0.3, seed=None)
                if s[2]:
                  x_out = tf.image.random_contrast(x_out, 0.7, 1)
                if s[3]:
                  saturation_factor = np.random.uniform(0.5, 1)
                  x_out = tf.image.adjust_saturation(x_out, saturation_factor)
                
                if s[5]:
                  x_out += np.random.uniform(0, 0.1, size=x_out.shape)
                
                obj_terms = train_step(x_in, y_in, x_out, thres)
            else:
                obj_terms = train_step(x_in, y_in)

            # Log every 50 batches
            if step % 20 == 0:
                #print(topic_model_pr.layers[0].get_weights()[0])
                for term in obj_terms:
                    logger.info(f'[STEP{step}] {term}: {obj_terms[term]}')
            for term in obj_terms:
                obj_terms[term] = obj_terms[term].numpy()
            obj_terms["epoch"] = epoch
            obj_terms["step"] = step
            df_obj = pd.Series(obj_terms)
            df_obj_terms = pd.concat([df_obj_terms, pd.DataFrame(df_obj).T], axis=0)
        
        train_acc = train_acc_metric.result()
        logger.info("Training acc over epoch: %.4f" % (float(train_acc),))
        
        # show timing information for the epoch
        epochEnd = time.time()
        elapsed = (epochEnd - epochStart) / 60.0
        logger.info("Time taken: %.2f minutes" % (elapsed))

        df_obj_terms = df_obj_terms.reset_index(drop=True)
        df_obj_terms_melt = pd.melt(df_obj_terms, id_vars=["epoch", "step"], 
                                    value_vars=[col for col in df_obj_terms.columns if col in 
                                                ['[ID] CE', '[ID] concept coherency', 'feature L2', 
                                                 '[ID] concept similarity', 'ood score difference', 
                                                 'id & ood separability', 'total loss']],
                                    var_name="loss_term", value_name="loss_value")

        plt.figure()
        sns.lineplot(data=df_obj_terms_melt, x="epoch", y="loss_value", hue="loss_term")
        plt.savefig(args.logdir+"/train_loss.png")
        plt.close()
        plt.figure()
        sns.lineplot(data=df_obj_terms_melt[(df_obj_terms_melt["loss_term"]=='[ID] CE') | (df_obj_terms_melt["loss_term"]=='[ID] concept coherency') | 
                                            (df_obj_terms_melt["loss_term"]=='[ID] concept similarity')], 
                     x="epoch", y="loss_value", hue="loss_term")
        plt.savefig(args.logdir+"/train_loss1.png")
        plt.close()


        # Reset training metrics at the end of each epoch
        train_acc_metric.reset_state()
        if epoch % args.save_step == 0:
            topic_model_pr.save_weights(os.path.join(args.logdir, args.name,'topic_epoch{}.weights.h5'.format(epoch)))

        if epoch % args.val_step == 0:
            _, logits_val, _ = topic_model_pr(feature_model.predict(val_loader), training=False)
            pred_val = softmax(logits_val)
            val_acc_metric.update_state(y_val, logits_val)
            val_acc = val_acc_metric.result()
            logger.info("[EPOCH %d] Validation acc: %.4f" % (epoch, float(val_acc)))
            val_acc_metric.reset_state()
            del logits_val
        
        logger.flush()


topic_vec = topic_model_pr.layers[0].get_weights()[0]   # 1, (2048, num_concepts)
# recov_vec = topic_model_pr.layers[-3].get_weights()[0]
topic_vec_n = topic_vec/(np.linalg.norm(topic_vec,axis=0,keepdims=True)+1e-9)
np.save(topic_savepath,topic_vec)
# np.save('results/Animals_with_Attributes2_energy_COCO/recov_vec_inceptionv3.npy',recov_vec)

assert np.shape(topic_vec)[1] == N_CONCEPT
# topic_model_pr.evaluate(f_test, y_test)
# f_val_recovered = topic_model_pr.predict(f_val)


f_test = feature_model.predict(test_loader)
_, logits_test, _ = topic_model_pr(f_test, training=False)
pred_test = softmax(logits_test)
test_acc_metric.update_state(y_test, logits_test)
test_acc = test_acc_metric.result()
logger.info('[ID TEST] Accuracy of topic model on test set: %f' %test_acc)

logger.flush()
# Out:
# Found 40670 images belonging to 1 classes.
# 2024-08-12 03:54:01,747 [INFO] utils.log:
# [INFO] starting epoch 1/40 ---------------------------------
# 2023
# WARNING:tensorflow:AutoGraph could not transform <function lower at 0x7f1afe533e20> and will run it as-is.
# Cause: Unable to locate the source code of <function lower at 0x7f1afe533e20>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2024-08-12 03:54:18,625 [WARNING] tensorflow: AutoGraph could not transform <function lower at 0x7f1afe533e20> and will run it as-is.
# Cause: Unable to locate the source code of <function lower at 0x7f1afe533e20>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function lower at 0x7f1afe533e20> and will run it as-is.
# Cause: Unable to locate the source code of <function lower at 0x7f1afe533e20>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0000 00:00:1723427690.278470 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.415313 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.416701 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.418079 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.419498 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.420895 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.422324 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.423798 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.425410 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.427020 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.428820 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.430629 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.432484 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.434396 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.436408 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.438411 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.440580 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.442909 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.445539 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.448398 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.452736 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.458471 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.476834 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.570102 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.570673 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.571247 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.571828 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.572490 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.573169 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.573848 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.574557 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.575265 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.576060 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.576858 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.577632 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.578400 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.579247 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.580209 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.581296 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.582335 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.583504 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.585102 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.586723 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.594244 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.594841 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.595410 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.595965 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.596528 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.597154 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.597815 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.598490 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.599189 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.599949 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.600654 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.601424 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.602165 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.602920 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.603757 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.604695 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.605757 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.606773 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.607918 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.609500 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.611074 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.618895 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.624018 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.624488 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.624966 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.625442 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.625967 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.626481 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.626993 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.627511 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.628064 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.628621 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.629167 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.629714 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.630319 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.631156 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.631992 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.632929 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.633831 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.634818 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.636083 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.637699 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.646479 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.675809 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.676464 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.677105 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.677747 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.678487 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.679254 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.680036 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.680841 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.681650 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.682618 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.683518 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.684416 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.685313 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.686315 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.687418 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.688714 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.689919 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.691340 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.693243 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.695175 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.702907 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.703559 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.704198 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.704824 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.705447 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.706141 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.706892 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.707654 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.708446 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.709365 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.710163 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.711033 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.711909 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.712784 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.713767 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.714831 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.716086 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.717262 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.718661 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.720544 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.722421 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.732161 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.775914 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.776632 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.777329 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.778041 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.778839 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.779671 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.780509 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.781385 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.782254 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.783308 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.784274 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.785246 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.786227 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.787305 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.788506 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.789910 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.791243 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.792781 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.794911 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.797055 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.799518 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.807586 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.808305 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.808995 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.809674 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.810372 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.811125 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.811941 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.812762 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.813624 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.814628 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.815497 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.816433 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.817383 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.818334 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.819404 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.820576 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.821944 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.823253 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.824754 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.826837 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.828932 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.831294 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.842465 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.942988 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.944162 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.945313 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.946536 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.947866 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.949197 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.950504 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.951818 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.953137 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.954542 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.955879 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.957291 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.958727 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.960381 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.961893 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.963429 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.964955 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.966627 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.968347 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.970192 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.974833 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.983923 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.984757 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.985554 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.986415 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.987269 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.988134 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.988996 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.989876 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.990739 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.991638 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.992610 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.993586 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.994599 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.995583 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.996684 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.997799 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427690.998848 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.000160 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.001517 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.002999 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.005743 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.017695 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.071307 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.072377 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.073490 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.074644 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.075805 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.077024 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.078164 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.079467 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.080780 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.082086 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.083556 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.084857 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.086104 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.087491 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.088798 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.090339 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.091856 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.093510 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.094840 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.096665 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.100817 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.179001 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.377514 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.378391 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.379211 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.380030 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.380782 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.381535 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.382308 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.383046 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.383820 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.384582 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.385348 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.386172 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.386875 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.387794 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.388640 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.389539 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.390465 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.391472 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.392503 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.393711 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.404039 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.404775 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.405662 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.406542 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.407373 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.408139 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.408900 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.409688 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.410428 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.411213 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.411981 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.412758 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.413673 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.414375 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.415350 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.416211 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.417232 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.418308 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.419410 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.420454 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.421669 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.432677 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.433555 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.434664 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.435763 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.436858 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.437839 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.438835 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.439702 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.440655 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.441647 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.442638 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.443655 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.444676 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.445817 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.447049 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.448217 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.449432 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.450578 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.451774 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.452834 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.454069 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.466246 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.470872 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.471388 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.471909 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.472427 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.473060 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.473571 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.474067 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.474563 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.475246 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.475935 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.476567 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.477203 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.477798 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.478403 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.479095 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.479850 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.480510 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.481148 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.481940 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.482877 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.493349 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.513447 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.514685 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.515917 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.517144 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.518179 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.519219 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.520278 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.521272 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.522321 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.523358 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.524391 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.525431 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.526374 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.527634 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.528807 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.530094 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.531353 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.532707 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.534175 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.535835 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.548662 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.549658 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.550928 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.552177 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.553432 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.554474 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.555517 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.556587 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.557592 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.558659 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.559708 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.560754 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.561945 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.562900 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.564296 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.565483 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.566940 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.568500 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.570010 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.571498 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.573176 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.587123 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.588337 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.589941 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.591523 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.593118 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.594502 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.595881 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.597081 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.598440 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.599827 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.601241 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.602694 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.604012 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.605655 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.607368 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.609046 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.610792 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.612470 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.614055 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.615549 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1723427691.617251 1257438 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# 2024-08-12 09:30:50,893 [INFO] utils.log: [STEP100] feature L2: 155.380126953125
# 2024-08-12 09:30:50,896 [INFO] utils.log: [STEP100] score difference: 0.42634350061416626
# 2024-08-12 09:30:50,898 [INFO] utils.log: [STEP100] separability: 0.024704452604055405
# 2024-08-12 09:30:50,900 [INFO] utils.log: [STEP100] total loss.......: 9.789848327636719
# 2024-08-12 09:35:11,705 [INFO] utils.log: Training acc over epoch: 0.7708
# 2024-08-12 09:35:11,708 [INFO] utils.log: Time taken: 29.97 minutes
# 2024-08-12 09:35:13,408 [INFO] utils.log:
# [INFO] starting epoch 12/40 ---------------------------------
# 2024-08-12 09:40:18,639 [INFO] utils.log: [STEP20] [ID] CE: 0.6203765869140625
# 2024-08-12 09:40:18,642 [INFO] utils.log: [STEP20] [ID] concept coherency: 0.6005159616470337
# 2024-08-12 09:40:18,645 [INFO] utils.log: [STEP20] [ID] concept similarity: 0.007600588258355856
# 2024-08-12 09:40:18,647 [INFO] utils.log: [STEP20] feature L2: 151.6265869140625
# 2024-08-12 09:40:18,649 [INFO] utils.log: [STEP20] score difference: 0.4822276532649994
# 2024-08-12 09:40:18,651 [INFO] utils.log: [STEP20] separability: 0.02979542873799801
# 2024-08-12 09:40:18,653 [INFO] utils.log: [STEP20] total loss.......: 8.84633731842041
# 2024-08-12 09:45:34,387 [INFO] utils.log: [STEP40] [ID] CE: 0.7675274610519409
# 2024-08-12 09:45:34,391 [INFO] utils.log: [STEP40] [ID] concept coherency: 0.5885478854179382
# 2024-08-12 09:45:34,393 [INFO] utils.log: [STEP40] [ID] concept similarity: 0.007975229062139988
# 2024-08-12 09:45:34,395 [INFO] utils.log: [STEP40] feature L2: 154.27880859375
# 2024-08-12 09:45:34,397 [INFO] utils.log: [STEP40] score difference: 0.4666193127632141
# 2024-08-12 09:45:34,399 [INFO] utils.log: [STEP40] separability: 0.02857428416609764
# 2024-08-12 09:45:34,401 [INFO] utils.log: [STEP40] total loss.......: 9.427587509155273
# 2024-08-12 09:50:47,296 [INFO] utils.log: [STEP60] [ID] CE: 0.9420048594474792
# 2024-08-12 09:50:47,300 [INFO] utils.log: [STEP60] [ID] concept coherency: 0.5876736044883728
# 2024-08-12 09:50:47,302 [INFO] utils.log: [STEP60] [ID] concept similarity: 0.00814604852348566
# 2024-08-12 09:50:47,304 [INFO] utils.log: [STEP60] feature L2: 159.04879760742188
# 2024-08-12 09:50:47,307 [INFO] utils.log: [STEP60] score difference: 0.5763947367668152
# 2024-08-12 09:50:47,309 [INFO] utils.log: [STEP60] separability: 0.02113223262131214
# 2024-08-12 09:50:47,311 [INFO] utils.log: [STEP60] total loss.......: 10.571391105651855
# 2024-08-12 09:55:59,869 [INFO] utils.log: [STEP80] [ID] CE: 0.8386108875274658
# 2024-08-12 09:55:59,872 [INFO] utils.log: [STEP80] [ID] concept coherency: 0.5966200232505798
# 2024-08-12 09:55:59,874 [INFO] utils.log: [STEP80] [ID] concept similarity: 0.008100301027297974
# 2024-08-12 09:55:59,876 [INFO] utils.log: [STEP80] feature L2: 154.54931640625
# 2024-08-12 09:55:59,878 [INFO] utils.log: [STEP80] score difference: 0.43375295400619507
# 2024-08-12 09:55:59,880 [INFO] utils.log: [STEP80] separability: 0.025089945644140244
# 2024-08-12 09:55:59,882 [INFO] utils.log: [STEP80] total loss.......: 9.587601661682129
# 2024-08-12 10:01:12,390 [INFO] utils.log: [STEP100] [ID] CE: 0.9801017045974731
# 2024-08-12 10:01:12,394 [INFO] utils.log: [STEP100] [ID] concept coherency: 0.5936973690986633
# 2024-08-12 10:01:12,396 [INFO] utils.log: [STEP100] [ID] concept similarity: 0.007998266257345676
# 2024-08-12 10:01:12,398 [INFO] utils.log: [STEP100] feature L2: 158.5514678955078
# 2024-08-12 10:01:12,400 [INFO] utils.log: [STEP100] score difference: 0.46361443400382996
# 2024-08-12 10:01:12,402 [INFO] utils.log: [STEP100] separability: 0.023649437353014946
# 2024-08-12 10:01:12,404 [INFO] utils.log: [STEP100] total loss.......: 10.259400367736816
# 2024-08-12 10:05:38,203 [INFO] utils.log: Training acc over epoch: 0.7726
# 2024-08-12 10:05:38,207 [INFO] utils.log: Time taken: 30.41 minutes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step
# 2024-08-12 10:07:02,242 [INFO] utils.log: [EPOCH 12] Validation acc: 0.8485
# 2024-08-12 10:07:02,245 [INFO] utils.log:
# [INFO] starting epoch 13/40 ---------------------------------
# 2024-08-12 10:12:41,729 [INFO] utils.log: [STEP20] [ID] CE: 0.8067196607589722
# 2024-08-12 10:12:41,732 [INFO] utils.log: [STEP20] [ID] concept coherency: 0.5939410328865051
# 2024-08-12 10:12:41,734 [INFO] utils.log: [STEP20] [ID] concept similarity: 0.008377769030630589
# 2024-08-12 10:12:41,736 [INFO] utils.log: [STEP20] feature L2: 156.13995361328125
# 2024-08-12 10:12:41,738 [INFO] utils.log: [STEP20] score difference: 0.5526642799377441
# 2024-08-12 10:12:41,740 [INFO] utils.log: [STEP20] separability: 0.02860177494585514
# 2024-08-12 10:12:41,742 [INFO] utils.log: [STEP20] total loss.......: 9.687657356262207
# 2024-08-12 10:18:03,918 [INFO] utils.log: [STEP40] [ID] CE: 0.8529496788978577
# 2024-08-12 10:18:03,922 [INFO] utils.log: [STEP40] [ID] concept coherency: 0.6044558882713318
# 2024-08-12 10:18:03,924 [INFO] utils.log: [STEP40] [ID] concept similarity: 0.008283616043627262
# 2024-08-12 10:18:03,927 [INFO] utils.log: [STEP40] feature L2: 158.90188598632812
# 2024-08-12 10:18:03,929 [INFO] utils.log: [STEP40] score difference: 0.5097916722297668
# 2024-08-12 10:18:03,931 [INFO] utils.log: [STEP40] separability: 0.02730177342891693
# 2024-08-12 10:18:03,933 [INFO] utils.log: [STEP40] total loss.......: 9.926118850708008
# 2024-08-12 10:23:15,782 [INFO] utils.log: [STEP60] [ID] CE: 0.7340471744537354
# 2024-08-12 10:23:15,785 [INFO] utils.log: [STEP60] [ID] concept coherency: 0.612495481967926
# 2024-08-12 10:23:15,787 [INFO] utils.log: [STEP60] [ID] concept similarity: 0.008452055975794792
# 2024-08-12 10:23:15,789 [INFO] utils.log: [STEP60] feature L2: 158.22042846679688
# 2024-08-12 10:23:15,792 [INFO] utils.log: [STEP60] score difference: 0.48523086309432983
# 2024-08-12 10:23:15,794 [INFO] utils.log: [STEP60] separability: 0.02023242600262165
# 2024-08-12 10:23:15,796 [INFO] utils.log: [STEP60] total loss.......: 9.989265441894531
# 2024-08-12 10:28:44,383 [INFO] utils.log: [STEP80] [ID] CE: 0.7029126286506653
# 2024-08-12 10:28:44,387 [INFO] utils.log: [STEP80] [ID] concept coherency: 0.5964343547821045
# 2024-08-12 10:28:44,389 [INFO] utils.log: [STEP80] [ID] concept similarity: 0.008522184565663338
# 2024-08-12 10:28:44,391 [INFO] utils.log: [STEP80] feature L2: 154.4965057373047
# 2024-08-12 10:28:44,393 [INFO] utils.log: [STEP80] score difference: 0.45118027925491333
# 2024-08-12 10:28:44,395 [INFO] utils.log: [STEP80] separability: 0.02994760498404503
# 2024-08-12 10:28:44,397 [INFO] utils.log: [STEP80] total loss.......: 9.227241516113281
# 2024-08-12 10:34:03,782 [INFO] utils.log: [STEP100] [ID] CE: 1.0154370069503784
# 2024-08-12 10:34:03,786 [INFO] utils.log: [STEP100] [ID] concept coherency: 0.5849283337593079
# 2024-08-12 10:34:03,788 [INFO] utils.log: [STEP100] [ID] concept similarity: 0.008725354447960854
# 2024-08-12 10:34:03,791 [INFO] utils.log: [STEP100] feature L2: 157.94395446777344
# 2024-08-12 10:34:03,793 [INFO] utils.log: [STEP100] score difference: 0.4416576623916626
# 2024-08-12 10:34:03,795 [INFO] utils.log: [STEP100] separability: 0.02380840852856636
# 2024-08-12 10:34:03,797 [INFO] utils.log: [STEP100] total loss.......: 10.299040794372559
# 2024-08-12 10:38:59,382 [INFO] utils.log: Training acc over epoch: 0.7739
# 2024-08-12 10:38:59,403 [INFO] utils.log: Time taken: 31.95 minutes
# 2024-08-12 10:39:01,387 [INFO] utils.log:
# [INFO] starting epoch 14/40 ---------------------------------
# 2024-08-12 10:44:12,741 [INFO] utils.log: [STEP20] [ID] CE: 0.746563196182251
# 2024-08-12 10:44:12,745 [INFO] utils.log: [STEP20] [ID] concept coherency: 0.5890752673149109
# 2024-08-12 10:44:12,748 [INFO] utils.log: [STEP20] [ID] concept similarity: 0.008545292541384697
# 2024-08-12 10:44:12,750 [INFO] utils.log: [STEP20] feature L2: 157.01199340820312
# 2024-08-12 10:44:12,752 [INFO] utils.log: [STEP20] score difference: 0.5616927146911621
# 2024-08-12 10:44:12,754 [INFO] utils.log: [STEP20] separability: 0.019499700516462326
# 2024-08-12 10:44:12,756 [INFO] utils.log: [STEP20] total loss.......: 10.229169845581055
# 2024-08-12 10:49:46,157 [INFO] utils.log: [STEP40] [ID] CE: 0.813098132610321
# 2024-08-12 10:49:46,161 [INFO] utils.log: [STEP40] [ID] concept coherency: 0.6089199185371399
# 2024-08-12 10:49:46,163 [INFO] utils.log: [STEP40] [ID] concept similarity: 0.008610304445028305
# 2024-08-12 10:49:46,166 [INFO] utils.log: [STEP40] feature L2: 156.35455322265625
# 2024-08-12 10:49:46,168 [INFO] utils.log: [STEP40] score difference: 0.48839181661605835
# 2024-08-12 10:49:46,170 [INFO] utils.log: [STEP40] separability: 0.023520030081272125
# 2024-08-12 10:49:46,173 [INFO] utils.log: [STEP40] total loss.......: 9.75784683227539
# 2024-08-12 10:55:20,198 [INFO] utils.log: [STEP60] [ID] CE: 0.8814196586608887
# 2024-08-12 10:55:20,202 [INFO] utils.log: [STEP60] [ID] concept coherency: 0.596057116985321
# 2024-08-12 10:55:20,204 [INFO] utils.log: [STEP60] [ID] concept similarity: 0.008762875571846962
# 2024-08-12 10:55:20,206 [INFO] utils.log: [STEP60] feature L2: 156.55076599121094
# 2024-08-12 10:55:20,208 [INFO] utils.log: [STEP60] score difference: 0.39536261558532715
# 2024-08-12 10:55:20,209 [INFO] utils.log: [STEP60] separability: 0.024658124893903732
# 2024-08-12 10:55:20,211 [INFO] utils.log: [STEP60] total loss.......: 9.826011657714844
# 2024-08-12 11:00:37,573 [INFO] utils.log: [STEP80] [ID] CE: 0.8776028156280518
# 2024-08-12 11:00:37,578 [INFO] utils.log: [STEP80] [ID] concept coherency: 0.6028632521629333
# 2024-08-12 11:00:37,580 [INFO] utils.log: [STEP80] [ID] concept similarity: 0.00873617734760046
# 2024-08-12 11:00:37,583 [INFO] utils.log: [STEP80] feature L2: 155.66526794433594
# 2024-08-12 11:00:37,586 [INFO] utils.log: [STEP80] score difference: 0.3832872807979584
# 2024-08-12 11:00:37,588 [INFO] utils.log: [STEP80] separability: 0.021514572203159332
# 2024-08-12 11:00:37,591 [INFO] utils.log: [STEP80] total loss.......: 9.810418128967285
# 2024-08-12 11:06:57,365 [INFO] utils.log: [STEP100] [ID] CE: 0.8936975002288818
# 2024-08-12 11:06:57,369 [INFO] utils.log: [STEP100] [ID] concept coherency: 0.5969390869140625
# 2024-08-12 11:06:57,371 [INFO] utils.log: [STEP100] [ID] concept similarity: 0.008856689557433128
# 2024-08-12 11:06:57,373 [INFO] utils.log: [STEP100] feature L2: 158.32757568359375
# 2024-08-12 11:06:57,375 [INFO] utils.log: [STEP100] score difference: 0.4329723119735718
# 2024-08-12 11:06:57,377 [INFO] utils.log: [STEP100] separability: 0.023145556449890137
# 2024-08-12 11:06:57,379 [INFO] utils.log: [STEP100] total loss.......: 10.121326446533203
# 2024-08-12 11:11:41,367 [INFO] utils.log: Training acc over epoch: 0.7746
# 2024-08-12 11:11:41,370 [INFO] utils.log: Time taken: 32.67 minutes
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 77s 5s/step
# 2024-08-12 11:13:12,422 [INFO] utils.log: [EPOCH 14] Validation acc: 0.8579
# 2024-08-12 11:13:12,425 [INFO] utils.log:
# [INFO] starting epoch 15/40 ---------------------------------
# 2024-08-12 11:18:33,043 [INFO] utils.log: [STEP20] [ID] CE: 0.8518707752227783
# 2024-08-12 11:18:33,047 [INFO] utils.log: [STEP20] [ID] concept coherency: 0.5886412262916565
# 2024-08-12 11:18:33,049 [INFO] utils.log: [STEP20] [ID] concept similarity: 0.008842642419040203
# 2024-08-12 11:18:33,051 [INFO] utils.log: [STEP20] feature L2: 154.8707275390625
# 2024-08-12 11:18:33,053 [INFO] utils.log: [STEP20] score difference: 0.47257310152053833
# 2024-08-12 11:18:33,055 [INFO] utils.log: [STEP20] separability: 0.027722885832190514
# 2024-08-12 11:18:33,057 [INFO] utils.log: [STEP20] total loss.......: 9.627387046813965
# 2024-08-12 11:24:05,063 [INFO] utils.log: [STEP40] [ID] CE: 1.0045757293701172
# 2024-08-12 11:24:05,084 [INFO] utils.log: [STEP40] [ID] concept coherency: 0.5862016677856445
# 2024-08-12 11:24:05,087 [INFO] utils.log: [STEP40] [ID] concept similarity: 0.008960041217505932
# 2024-08-12 11:24:05,089 [INFO] utils.log: [STEP40] feature L2: 157.86288452148438
# 2024-08-12 11:24:05,091 [INFO] utils.log: [STEP40] score difference: 0.37241947650909424
# 2024-08-12 11:24:05,093 [INFO] utils.log: [STEP40] separability: 0.027071889489889145
# 2024-08-12 11:24:05,095 [INFO] utils.log: [STEP40] total loss.......: 10.037272453308105
# 2024-08-12 11:29:44,253 [INFO] utils.log: [STEP60] [ID] CE: 0.8348023891448975
# 2024-08-12 11:29:44,257 [INFO] utils.log: [STEP60] [ID] concept coherency: 0.6063306927680969
# 2024-08-12 11:29:44,259 [INFO] utils.log: [STEP60] [ID] concept similarity: 0.009172800928354263
# 2024-08-12 11:29:44,261 [INFO] utils.log: [STEP60] feature L2: 153.82162475585938
# 2024-08-12 11:29:44,263 [INFO] utils.log: [STEP60] score difference: 0.6548573970794678
# 2024-08-12 11:29:44,265 [INFO] utils.log: [STEP60] separability: 0.027080709114670753
# 2024-08-12 11:29:44,267 [INFO] utils.log: [STEP60] total loss.......: 9.546208381652832
# 2024-08-12 11:34:54,480 [INFO] utils.log: [STEP80] [ID] CE: 0.87608802318573
# 2024-08-12 11:34:54,483 [INFO] utils.log: [STEP80] [ID] concept coherency: 0.6151744723320007
# 2024-08-12 11:34:54,486 [INFO] utils.log: [STEP80] [ID] concept similarity: 0.009325754828751087
# 2024-08-12 11:34:54,488 [INFO] utils.log: [STEP80] feature L2: 155.65042114257812
# 2024-08-12 11:34:54,490 [INFO] utils.log: [STEP80] score difference: 0.5431655049324036
# 2024-08-12 11:34:54,493 [INFO] utils.log: [STEP80] separability: 0.02318286895751953
# 2024-08-12 11:34:54,495 [INFO] utils.log: [STEP80] total loss.......: 9.7666654586792
# 2024-08-12 11:41:00,958 [INFO] utils.log: [STEP100] [ID] CE: 0.9393205642700195
# 2024-08-12 11:41:01,001 [INFO] utils.log: [STEP100] [ID] concept coherency: 0.6071364283561707
# 2024-08-12 11:41:01,003 [INFO] utils.log: [STEP100] [ID] concept similarity: 0.008987206034362316
# 2024-08-12 11:41:01,005 [INFO] utils.log: [STEP100] feature L2: 160.2340545654297
# 2024-08-12 11:41:01,006 [INFO] utils.log: [STEP100] score difference: 0.5041471123695374
# 2024-08-12 11:41:01,008 [INFO] utils.log: [STEP100] separability: 0.024132028222084045
# 2024-08-12 11:41:01,010 [INFO] utils.log: [STEP100] total loss.......: 10.278779029846191
# 2024-08-12 11:45:59,739 [INFO] utils.log: Training acc over epoch: 0.7658
# 2024-08-12 11:45:59,742 [INFO] utils.log: Time taken: 32.79 minutes
# 2024-08-12 11:46:02,019 [INFO] utils.log:
# [INFO] starting epoch 16/40 ---------------------------------
# 2024-08-12 11:51:58,614 [INFO] utils.log: [STEP20] [ID] CE: 1.0648876428604126
# 2024-08-12 11:51:58,618 [INFO] utils.log: [STEP20] [ID] concept coherency: 0.5844398140907288
# 2024-08-12 11:51:58,620 [INFO] utils.log: [STEP20] [ID] concept similarity: 0.00924950186163187
# 2024-08-12 11:51:58,622 [INFO] utils.log: [STEP20] feature L2: 157.9887237548828
# 2024-08-12 11:51:58,623 [INFO] utils.log: [STEP20] score difference: 0.5754691362380981
# 2024-08-12 11:51:58,625 [INFO] utils.log: [STEP20] separability: 0.019548634067177773
# 2024-08-12 11:51:58,627 [INFO] utils.log: [STEP20] total loss.......: 10.709895133972168
# 2024-08-12 11:58:19,895 [INFO] utils.log: [STEP40] [ID] CE: 0.8656221032142639
# 2024-08-12 11:58:19,899 [INFO] utils.log: [STEP40] [ID] concept coherency: 0.6115833520889282
# 2024-08-12 11:58:19,901 [INFO] utils.log: [STEP40] [ID] concept similarity: 0.009175501763820648
# 2024-08-12 11:58:19,903 [INFO] utils.log: [STEP40] feature L2: 150.9696044921875
# 2024-08-12 11:58:19,905 [INFO] utils.log: [STEP40] score difference: 0.47197026014328003
# 2024-08-12 11:58:19,907 [INFO] utils.log: [STEP40] separability: 0.0253149326890707
# 2024-08-12 11:58:19,909 [INFO] utils.log: [STEP40] total loss.......: 9.14472770690918
# 2024-08-12 12:05:41,928 [INFO] utils.log: [STEP60] [ID] CE: 0.9269075393676758
# 2024-08-12 12:05:41,930 [INFO] utils.log: [STEP60] [ID] concept coherency: 0.5840680003166199
# 2024-08-12 12:05:41,932 [INFO] utils.log: [STEP60] [ID] concept similarity: 0.00903643760830164
# 2024-08-12 12:05:41,934 [INFO] utils.log: [STEP60] feature L2: 156.142578125
# 2024-08-12 12:05:41,936 [INFO] utils.log: [STEP60] score difference: 0.392929345369339
# 2024-08-12 12:05:41,937 [INFO] utils.log: [STEP60] separability: 0.026298196986317635
# 2024-08-12 12:05:41,939 [INFO] utils.log: [STEP60] total loss.......: 9.868868827819824
